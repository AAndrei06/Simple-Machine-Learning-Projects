# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('salary.csv')

# %%
X_data = pd.DataFrame(data.YearsExperience)
Y_data = pd.DataFrame(data.Salary)

# %%
model = LinearRegression()
#x_train,x_test,y_train,y_test = train_test_split(X_data,Y_data,test_size = 0.2)
model.fit(X_data,Y_data)
# model.score(x_test,y_test)*100
# Out:
# LinearRegression()

# %%
plt.scatter(X_data,Y_data)
plt.plot(np.linspace(0,11,100).reshape(-1,1),model.predict(np.linspace(0,11,100).reshape(-1,1)),c = 'r')
# Out:
# /home/andrei/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f'{model.predict(np.array([3]).reshape(-1,1))[0,0]:.2f} $')
# Out:
# 54142.09 $
# /home/andrei/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
