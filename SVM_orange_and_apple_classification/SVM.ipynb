# %%
from sklearn.datasets import load_svmlight_file
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('apples_and_oranges.csv',index_col = False)
X = df.drop(['Class'],axis = 1)
Y = df['Class']

# %%
enc = LabelEncoder()
enc.fit(Y.unique())
# Out:
# LabelEncoder()

# %%
Y = enc.transform(Y)

# %%
model = SVC(kernel='linear')
model.fit(X,Y)
w = model.coef_[0]
a = -w[0]/w[1]
xx = np.linspace(64,76)
yy = a * xx - model.intercept_[0] / w[1]
plt.scatter(X.iloc[:,0],X.iloc[:,1],c = Y)
plt.plot(xx,yy,c = 'red')
plt.ylim([3.5,6.5])
plt.show()

# %%
'''
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.92)
model.score(x_test,y_test)
'''
# Out:
# '\nx_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.92)\nmodel.score(x_test,y_test)\n'

# %%
df['Class'].unique()[model.predict(np.array([[66],[4.5]]).reshape(1,-1))[0]]
# Out:
# /home/andrei/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 'apple'
